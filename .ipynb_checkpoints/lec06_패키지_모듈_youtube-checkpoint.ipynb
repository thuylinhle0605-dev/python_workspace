# %% [markdown]
# # **Lec06. 패키지  & 모듈 & 클래스 & 함수**

# %%
package _modul_ class_def

# %%
`` python

from 패키지.모듈 import 클래스
from 패키지.모듈 import 함수, 함수2  ...  *

from       모듈 import 클래스       ---- 클래스.a
from       모듈 import 함수, add    ---- add(4,5)
                import 모듈         ---- 모듈.add(4,5)

# %%
a = 10
b = 20
print(a + b)
# Out:
# 30

# %% [markdown]
# # **[실습] youtube-search-python API 활용**
# * pip install youtube-search-python
# * https://github.com/alexmercerind/youtube-search-python
# * lib proxy 버전 업데이트
#     * pip uninstall httpx -y
#     * pip install httpx==0.27.2

# %%
mydic = {"result" : 10 }

# %%
# from youtubesearchpython.search import Search
from youtubesearchpython import VideosSearch
res = VideosSearch('나루토', limit = 2)2)

prresarch.resul  t())
# Out:
#   Cell In[1], line 3
#     resch = VideosSear('c루토's', limit = 2)
#                              ^
# SyntaxError: unterminated string literal (detected at line 3)

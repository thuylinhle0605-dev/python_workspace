# %% [markdown]
# # **10 minutes to pandas**
# * https://pandas.pydata.org/docs/user_guide/10min.html#
# * pip install numpy, pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # **기본 구조**
# * <font color=red><b>Series: 1차 데이터
# * <font color=red><b>DataFrame: 2차 데이터 (like table)

# %% [markdown]
# <img src="https://miro.medium.com/v2/resize:fit:1100/format:webp/1*OaUbgSxKnC_kaRj0H6vK5Q.jpeg" widcth=400>
# <pre>  단일값[0]   리스트,튜플,딕[1]    Series[1]      DataFrame[2]             Tensor[3]

# %% [markdown]
# # **C:생성**

# %%
mylist = [1, 3, 5, np.nan, 6, 8]
print(mylist)
s = pd.Series(mylist)
print(s)
# Out:
# [1, 3, 5, nan, 6, 8]
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
mylist =[ [1, 3, 5, np.nan, 6, 8],
          [1, 3, 5, np.nan, 6, 8],
          [1, 3, 5, np.nan, 6, 8]
        ]
df = pd.DataFrame(mylist, index=[10,20,30], columns=['a','b','c','d','e','f'])
print(df)  

df
# Out:
#     a  b  c   d  e  f
# 10  1  3  5 NaN  6  8
# 20  1  3  5 NaN  6  8
# 30  1  3  5 NaN  6  8
#     a  b  c   d  e  f
# 10  1  3  5 NaN  6  8
# 20  1  3  5 NaN  6  8
# 30  1  3  5 NaN  6  8

# %%
df.dtypes
# Out:
# a    int64
# b    int64
# c    int64
# dtype: object

# %%
mydict = {"a":[1,1,1], "b":[3,3,3,], "c":[5,5,5]}
df1 = pd.DataFrame(mydict)
df1
# Out:
#    a  b  c
# 0  1  3  5
# 1  1  3  5
# 2  1  3  5

# %%
df1.dtypes
# Out:
# a    int64
# b    int64
# c    int64
# dtype: object

# %%
mylist1= [5,6,10]
a = pd.Series(mylist1)
print(a)
# Out:
# 0     5
# 1     6
# 2    10
# dtype: int64

# %%
mydict1={"stt":[1,2,3], "name":["Linh","Lan","Min"],"age":[20,30,14]}
b = pd.DataFrame(mydict1)
print(b)

b
# Out:
#    stt  name  age
# 0    1  Linh   20
# 1    2   Lan   30
# 2    3   Min   14
#    stt  name  age
# 0    1  Linh   20
# 1    2   Lan   30
# 2    3   Min   14

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df.dtype
#
# File C:\IT\python_workspace\.venv\Lib\site-packages\pandas\core\generic.py:6194, in NDFrame.__getattr__(self, name)
#    6187 if (
#    6188     name not in self._internal_names_set
#    6189     and name not in self._metadata
#    6190     and name not in self._accessors
#    6191     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192 ):
#    6193     return self[name]
# -> 6194 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
df.head()
# Out:
#    a  b  c
# 0  1  3  5
# 1  1  3  5
# 2  1  3  5

# %% [markdown]
# # **Lec06. 패키지 & 모듈  & 클래스 & 함수**
# * module (파일) - package (폴더) - class - def

# %% [markdown]
# ``` python
#
# from  (패키지.)모듈 import 클래스       ---- 클래스.add(4,5)
# from  (패키지.)모듈 import 함수, add *  ---- add(4,5)
#                    import 모듈         ---- 모듈.add(4,5)
#                    import 모듈 as aa   ---- aa.add(4,5)

# %% [markdown]
# lec07 ~ lec09 참조

# %% [markdown]
# # **[실습] KAKAO REST API(JSON)**

# %%
mydic = {"result" :       [1,  {"age": [30,20,10] } ,  [10,20]  ]        }
print(  mydic["result"] )
print("--"*20)
print(  mydic["result"][0] )
print(  mydic["result"][1] )
print(  mydic["result"][2] )
print("--"*20)
print(  mydic["result"][1]['age'] )
print(  mydic["result"][1]['age'][0] )
print(  mydic["result"][2][1] )
# Out:
# [1, {'age': [30, 20, 10]}, [10, 20]]
# ----------------------------------------
# 1
# {'age': [30, 20, 10]}
# [10, 20]
# ----------------------------------------
# [30, 20, 10]
# 30
# 20

# %% [markdown]
# * https://developers.kakao.com/docs/ko/kakaologin/rest-api#shipping-address-info

# %%
mydic = {
  "user_id"                : 9876543211234,
  "shipping_addresses"     :    [
                                        {
                                          "id": 319,
                                          "name": "회사",
                                          "base_address": "경기 성남시 분당구 판교역로 231 (삼평동, 에이치스퀘어 에스동)",
                                          "receiver_phone_number1": "031-123-2345"
                                        },
                                        {
                                          "id": 320,
                                          "name": "회사",
                                          "base_address": "경기 성남시 분당구 삼평동 680 (삼평동, 에이치스퀘어 에스동)",
                                          "receiver_phone_number1": "010-0056-1234"
                                        }
                                  ]
        }
print ( mydic["shipping_addresses"][0]["base_address"] )
# Out:
# 경기 성남시 분당구 판교역로 231 (삼평동, 에이치스퀘어 에스동)

# %% [markdown]
# * https://developers.kakao.com/docs/ko/kakaologin/rest-api#user-info-list

# %%
mydic = [
              {
                "id": 1399634384,
                "connected_at"  : "2020-07-06T09:55:51Z",
                "kakao_account" : {
                                      "profile"     : {
                                                          "nickname": "춘식이",
                                                       },
                                      "email"       : "sweetpotato@kakao.com"
                                   }
              },
              {
                "id": 1406264199,
                "connected_at": "2020-07-14T06:15:36Z",
                "kakao_account": {
               
                  "profile": {
                    "nickname": "나비",
                  },
                  "email": "abc@kakao.com"
                }
              }
]
mydic[0]["kakao_account"]["profile"]["nickname"]
# Out:
# '춘식이'

# %%
for v in mydic : 
    print( v["kakao_account"]["profile"]["nickname"] )
# Out:
# 춘식이
# 나비

# %%
for i, v in enumerate(mydic) : 
    print( mydic[i]["kakao_account"]["profile"]["nickname"] )
# Out:
# 춘식이
# 나비

# %% [markdown]
# # **[실습] youtube-search-python API 활용**
# * pip install youtube-search-python
# * https://github.com/alexmercerind/youtube-search-python
# * lib proxy 버전 업데이트
#     - pip uninstall httpx -y
#     - pip install httpx==0.27.2

# %%
# from youtubesearchpython.search import VideosSearch
from youtubesearchpython import VideosSearch
from pprint import pprint

res = VideosSearch('뽀로로', limit = 5)
# pprint(res.result())

data = res.result()
for v in data['result'] :
    print(v['title'])
    print(v['thumbnails'][0]['url'])
    print(v['link'])
    print("---"*20)
# Out:
# 뽀롱뽀롱 뽀로로 9기 전편 연속 재생 | 뽀로로 이야기 | 뽀로로 인기본편 | 뽀롱뽀롱뽀로로
# https://i.ytimg.com/vi/ZshH8LC5zXA/hq720.jpg?v=6a7ead81&sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCUsqWyo_mR5PXjJsPwQhHee-hgng
# https://www.youtube.com/watch?v=ZshH8LC5zXA
# ------------------------------------------------------------
# 뽀로로 이야기 | 연휴에 몰아보는 뽀로로 인기 본편 | TV로 보는 뽀로로 | 뽀로로 3시간 이어보기 | 뽀롱뽀롱 뽀로로
# https://i.ytimg.com/vi/qwIEziCjSUo/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDvyvpX_Do78-GIyIQkwtBz59StMw
# https://www.youtube.com/watch?v=qwIEziCjSUo
# ------------------------------------------------------------
# 뽀로로 이야기 | 이야! 여름이다! 물놀이 이야기 모음집 (+1시간) | 티비로 몰아보는 뽀로로 인기 에피소드 | 뽀로로 1시간 이어보기
# https://i.ytimg.com/vi/K4B_yNbg5lQ/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBa69g21hiEIVzuMxF96bl7Y8RZuw
# https://www.youtube.com/watch?v=K4B_yNbg5lQ
# ------------------------------------------------------------
# 뽀로로 이야기 | 뽀롱뽀롱 세균 퇴치 | 뽀로로 8기 | TV로 보는 뽀로로 | 주말에 보는 뽀로로 | 뽀로로 3시간 | 뽀롱뽀롱 뽀로로
# https://i.ytimg.com/vi/cOCXcjbtOOI/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCI-dWJuXvGpDHfJvKXf_ra2htjlA
# https://www.youtube.com/watch?v=cOCXcjbtOOI
# ------------------------------------------------------------
# 차에서 듣기 좋은 동요 모음집 (30분) | 뽀로로 동요 연속 듣기 | 뽀로로 인기 동요 BEST 모음 | 뽀로로와노래해요
# https://i.ytimg.com/vi/DK0c-Ka4AyM/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDFSCIMRhCUgd-dgz79Gh16XeyfTA
# https://www.youtube.com/watch?v=DK0c-Ka4AyM
# ------------------------------------------------------------

# %% [markdown]
# # **[실습] 공공데이터포털**
# * https://www.data.go.kr
# * https://www.data.go.kr/data/15058601/openapi.do
# * 김해시 공사 : https://www.gimhae.go.kr/00761/00832/05867.web
# * pip install requests

# %%
import requests

url = "http://www.gimhae.go.kr/openapi/tour/restaurant.do"

headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/151.0.0.0 Safari/537.36"
    ),
    "Accept": "application/json, text/javascript, */*; q=0.01",
    "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "Referer": "https://www.gimhae.go.kr/",
}


res = requests.get(
    url,
    headers=headers,
    timeout=10
)

print(res.status_code) #여기가 정상이라면 200이 온다고 함
data = res.json()
print(data['results'])
# Out:
# 200
# [{'idx': 1604, 'name': '(유)아웃백스테이크하우스코리아 김해신세계점', 'category': '양식', 'area': '내외동', 'phone': '02-2054-8365', 'address': '경상남도 김해시 김해대로 2232 (외동) 4층', 'homepage': '', 'businesshour': '전화문의', 'holiday': '전화문의', 'content': '', 'menuprice': '', 'xposition': '35.2293396295983', 'yposition': '128.872242572055', 'multifileId': 'MF00007883', 'images': []}, {'idx': 1243, 'name': '(유)아웃백스테이크하우스코리아 김해점', 'category': '양식', 'area': '내외동', 'phone': '055-337-6191', 'address': '경상남도 김해시 내외중앙로 76 (내동) ', 'homepage': '', 'businesshour': '전화문의', 'holiday': '전화문의', 'content': '', 'menuprice': '', 'xposition': '35.2367156289288', 'yposition': '128.867421932123', 'multifileId': 'MF00006381', 'images': []}, {'idx': 547, 'name': '(유)아웃백스테이크하우스코리아 김해점', 'category': '양식', 'area': '내외동', 'phone': '055-337-6191', 'address': '경상남도 김해시 내외중앙로 76, 2층 (내동, 서울빌딩)', 'homepage': '', 'businesshour': '전화문의', 'holiday': '전화문의', 'content': '이 업소는 생활방역을 준수하는 안심식당입니다.', 'menuprice': '', 'xposition': '35.2367156289288', 'yposition': '128.867421932123', 'multifileId': 'MF00004081', 'images': ['https://www.gimhae.go.kr/CmsMultiFile/view.do?multifileId=MF00004081&idx=23988']}, {'idx': 488, 'name': '(주)가야유통 장유휴게소 (스넥코너)', 'category': '한식', 'area': '장유1동', 'phone': '055-313-2610', 'address': '경상남도 김해시 장유로116번길 44-82 (부곡동, 장유휴게소)', 'homepage': '', 'businesshour': '전화문의', 'holiday': '전화문의', 'content': '이 업소는 생활방역을 준수하는 안심식당입니다.', 'menuprice': '', 'xposition': '35.2124648669912', 'yposition': '128.793845393654', 'multifileId': 'MF00004017', 'images': ['https://www.gimhae.go.kr/CmsMultiFile/view.do?multifileId=MF00004017&idx=23929']}, {'idx': 913, 'name': '(주)가야유통장유휴게소(로띠번)', 'category': '기타', 'area': '장유1동', 'phone': '055-313-2610', 'address': '경상남도 김해시 장유로116번길 44-82 (부곡동) , 장유휴게소 내', 'homepage': '', 'businesshour': '09시~17시', 'holiday': '연중 무휴', 'content': '* 당사는 남해고속도로 제2지선 서부산 방향에 있는 고속도로 휴게소내 로띠번 매장입니다.\r\n  친절한 응대 및 맛있는 메뉴로 항상 고객 여러분께 최선을 다 할 것을 약속드립니다.\r\n\r\n - 좌석수: 40석\r\n - 주차장정보: 109대\r\n - 카드사용: 가능\r\n - 화장실: 있음\r\n - 음식포장: 불가', 'menuprice': '로띠번, 아메리카노 커피', 'xposition': '35.2124648669912', 'yposition': '128.793845393654', 'multifileId': 'MF00004675', 'images': ['https://www.gimhae.go.kr/CmsMultiFile/view.do?multifileId=MF00004675&idx=24556', 'https://www.gimhae.go.kr/CmsMultiFile/view.do?multifileId=MF00004675&idx=24558', 'https://www.gimhae.go.kr/CmsMultiFile/view.do?multifileId=MF00004675&idx=24557']}, {'idx': 915, 'name': '(주)가야유통장유휴게소(스넥코너)', 'category': '기타', 'area': '장유1동', 'phone': '055-313-2610', 'address': '경상남도 김해시 장유로116번길 44-82 (부곡동) 장유휴게소 내', 'homepage': '', 'businesshour': '09시~17시', 'holiday': '연중 무휴', 'content': '* 당사는 남해고속도로 제2지선 서부산 방향에 있는 고속도로 휴게소내 스넥코너입니다.\r\n  친절한 안내 및 맛있는 메뉴로 항상 고객 여러분께 최선을 다 할 것을 약속드립니다.\r\n\r\n - 좌석수: 40석\r\n - 주차장정보: 109대\r\n - 카드사용: 가능\r\n - 화장실: 있음\r\n - 음식포장: 불가', 'menuprice': '호두과자, 핫바', 'xposition': '35.2124648669912', 'yposition': '128.793845393654', 'multifileId': 'MF00004677', 'images': ['https://www.gimhae.go.kr/CmsMultiFile/view.do?multifileId=MF00004677&idx=24564', 'https://www.gimhae.go.kr/CmsMultiFile/view.do?multifileId=MF00004677&idx=24562', 'https://www.gimhae.go.kr/CmsMultiFile/view.do?multifileId=MF00004677&idx=24563']}, {'idx': 914, 'name': '(주)가야유통장유휴게소(엔제리너스)', 'category': '카페', 'area': '장유1동', 'phone': '055-313-2610', 'address': '경상남도 김해시 장유로116번길 44-82 (부곡동) 장유휴게소 내', 'homepage': '', 'businesshour': '09시~17시', 'holiday': '연중 무휴', 'content': '* 당사는 남해고속도로 제2지선 서부산 방향에 있는 고속도로 휴게소내 엔제리너스 커피입니다.\r\n  친절한 안내 및 맛있는 메뉴로 항상 고객 여러분께 최선을 다 할 것을 약속드립니다.\r\n\r\n - 좌석수: 40석\r\n - 주차장정보: 50대\r\n - 카드사용: 가능\r\n - 화장실: 있음\r\n - 음식포장: 불가', 'menuprice': '아메리카노, 카페라떼', 'xposition': '35.2124648669912', 'yposition': '128.793845393654', 'multifileId': 'MF00004676', 'images': ['https://www.gimhae.go.kr/CmsMultiFile/view.do?multifileId=MF00004676&idx=24559', 'https://www.gimhae.go.kr/CmsMultiFile/view.do?multifileId=MF00004676&idx=24561', 'https://www.gimhae.go.kr/CmsMultiFile/view.do?multifileId=MF00004676&idx=24560']}, {' ...

# %%
print(data["results"][0]  ['name'])
print(data["results"][0]  ['category'])
print(data["results"][0]  ['phone'])
print(data["results"][0]  ['address'])
# Out:
# (유)아웃백스테이크하우스코리아 김해신세계점
# 양식
# 02-2054-8365
# 경상남도 김해시 김해대로 2232 (외동) 4층

# %%
for v in data["results"] :
    print(v['name'] , v['category'], v['phone'], v['address'], v['xposition'],  v['yposition']) 
    print("--"*20)
# Out:
# (유)아웃백스테이크하우스코리아 김해신세계점 양식 02-2054-8365 경상남도 김해시 김해대로 2232 (외동) 4층 35.2293396295983 128.872242572055
# ----------------------------------------
# (유)아웃백스테이크하우스코리아 김해점 양식 055-337-6191 경상남도 김해시 내외중앙로 76 (내동)  35.2367156289288 128.867421932123
# ----------------------------------------
# (유)아웃백스테이크하우스코리아 김해점 양식 055-337-6191 경상남도 김해시 내외중앙로 76, 2층 (내동, 서울빌딩) 35.2367156289288 128.867421932123
# ----------------------------------------
# (주)가야유통 장유휴게소 (스넥코너) 한식 055-313-2610 경상남도 김해시 장유로116번길 44-82 (부곡동, 장유휴게소) 35.2124648669912 128.793845393654
# ----------------------------------------
# (주)가야유통장유휴게소(로띠번) 기타 055-313-2610 경상남도 김해시 장유로116번길 44-82 (부곡동) , 장유휴게소 내 35.2124648669912 128.793845393654
# ----------------------------------------
# (주)가야유통장유휴게소(스넥코너) 기타 055-313-2610 경상남도 김해시 장유로116번길 44-82 (부곡동) 장유휴게소 내 35.2124648669912 128.793845393654
# ----------------------------------------
# (주)가야유통장유휴게소(엔제리너스) 카페 055-313-2610 경상남도 김해시 장유로116번길 44-82 (부곡동) 장유휴게소 내 35.2124648669912 128.793845393654
# ----------------------------------------
# (주)김덕규과자점 기타 070-8888-6610 경상남도 김해시 장유로 469 (신문동)  35.1850621204763 128.829596369018
# ----------------------------------------
# (주)스타벅스 김해내동점 카페 055-338-7421 경상남도 김해시 경원로 67 (내동)  35.2371561314489 128.867509360481
# ----------------------------------------
# (주)스타벅스 김해대로DT점 카페 055-338-9826 경상남도 김해시 김해대로 2465 (삼정동)  35.2279428522551 128.896463830438
# ----------------------------------------
